# %%
from transformers import GPT2LMHeadModel, AutoTokenizer

model = GPT2LMHeadModel.from_pretrained("nsarrazin/chessformer").eval()
tokenizer = AutoTokenizer.from_pretrained("nsarrazin/chessformer")

moves = " ".join(["e2e4", "e7e5", "d2d4", "d7d5"])

model_inputs = tokenizer(moves, return_tensors="pt")
gen_tokens = model.generate(**model_inputs, max_new_tokens=1)[0]
next_move = tokenizer.decode(gen_tokens[-1])

print(next_move) #d4e5
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 9
#       6 moves = " ".join(["e2e4", "e7e5", "d2d4", "d7d5"])
#       8 model_inputs = tokenizer(moves, return_tensors="pt")
# ----> 9 gen_tokens = model.generate(**model_inputs, max_new_tokens=1)[0]
#      10 next_move = tokenizer.decode(gen_tokens[-1])
#      12 print(next_move) #d4e5
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\transformers\generation\utils.py:2465, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2457     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2458         input_ids=input_ids,
#    2459         expand_size=generation_config.num_return_sequences,
#    2460         is_encoder_decoder=self.config.is_encoder_decoder,
#    2461         **model_kwargs,
#    2462     )
#    2464     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2465     result = self._sample(
#    2466         input_ids,
#    2467         logits_processor=prepared_logits_processor,
#    2468         stopping_criteria=prepared_stopping_criteria,
#    2469         generation_config=generation_config,
#    2470         synced_gpus=synced_gpus,
#    2471         streamer=streamer,
#    2472         **model_kwargs,
#    2473     )
#    2475 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2476     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2477     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2478         input_ids=input_ids,
#    2479         expand_size=generation_config.num_beams,
#    2480         is_encoder_decoder=self.config.is_encoder_decoder,
#    2481         **model_kwargs,
#    2482     )
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\transformers\generation\utils.py:3431, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3428 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3430 if is_prefill:
# -> 3431     outputs = self(**model_inputs, return_dict=True)
#    3432     is_prefill = False
#    3433 else:
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\transformers\models\gpt2\modeling_gpt2.py:1062, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1054 r"""
#    1055 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1056     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#    1057     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#    1058     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1059 """
#    1060 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1062 transformer_outputs = self.transformer(
#    1063     input_ids,
#    1064     past_key_values=past_key_values,
#    1065     attention_mask=attention_mask,
#    1066     token_type_ids=token_type_ids,
#    1067     position_ids=position_ids,
#    1068     head_mask=head_mask,
#    1069     inputs_embeds=inputs_embeds,
#    1070     encoder_hidden_states=encoder_hidden_states,
#    1071     encoder_attention_mask=encoder_attention_mask,
#    1072     use_cache=use_cache,
#    1073     output_attentions=output_attentions,
#    1074     output_hidden_states=output_hidden_states,
#    1075     return_dict=return_dict,
#    1076 )
#    1077 hidden_states = transformer_outputs[0]
#    1079 # Set device for model parallelism
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\transformers\models\gpt2\modeling_gpt2.py:922, in GPT2Model.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     910     outputs = self._gradient_checkpointing_func(
#     911         block.__call__,
#     912         hidden_states,
#    (...)    919         output_attentions,
#     920     )
#     921 else:
# --> 922     outputs = block(
#     923         hidden_states,
#     924         layer_past=layer_past,
#     925         attention_mask=attention_mask,
#     926         head_mask=head_mask[i],
#     927         encoder_hidden_states=encoder_hidden_states,
#     928         encoder_attention_mask=encoder_attention_mask,
#     929         use_cache=use_cache,
#     930         output_attentions=output_attentions,
#     931     )
#     933 hidden_states = outputs[0]
#     934 if use_cache is True:
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\transformers\models\gpt2\modeling_gpt2.py:403, in GPT2Block.forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     391 def forward(
#     392     self,
#     393     hidden_states: Optional[Tuple[torch.FloatTensor]],
#    (...)    400     output_attentions: Optional[bool] = False,
#     401 ) -> Union[Tuple[torch.Tensor], Optional[Tuple[torch.Tensor, Tuple[torch.FloatTensor, ...]]]]:
#     402     residual = hidden_states
# --> 403     hidden_states = self.ln_1(hidden_states)
#     404     attn_outputs = self.attn(
#     405         hidden_states,
#     406         layer_past=layer_past,
#    (...)    410         output_attentions=output_attentions,
#     411     )
#     412     attn_output = attn_outputs[0]  # output_attn: a, present, (attentions)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\modules\normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\nn\functional.py:2910, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2900 if has_torch_function_variadic(input, weight, bias):
#    2901     return handle_torch_function(
#    2902         layer_norm,
#    2903         (input, weight, bias),
#    (...)   2908         eps=eps,
#    2909     )
# -> 2910 return torch.layer_norm(
#    2911     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2912 )
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_decomp\__init__.py:113, in _convert_out_params.<locals>._fn(*args, **kwargs)
#     111 is_none = out_kwargs[0] is None
#     112 assert all((o is None) == is_none for o in out_kwargs)
# --> 113 return f(*args, **kwargs, out=None if is_none else out_kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_prims_common\wrappers.py:308, in out_wrapper.<locals>._out_wrapper.<locals>._fn(out, *args, **kwargs)
#     306     result = fn(*args, is_out=(out is not None), **kwargs)  # type: ignore[arg-type]
#     307 else:
# --> 308     result = fn(*args, **kwargs)
#     309 assert (
#     310     (isinstance(result, TensorLike) and is_tensor)
#     311     or (
#    (...)    318     )
#     319 )
#     320 # unbind_copy is a special case: see https://github.com/pytorch/pytorch/issues/130829
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_refs\__init__.py:3283, in native_layer_norm(input, normalized_shape, weight, bias, eps)
#    3281     out = out * weight
#    3282 elif weight is not None and bias is not None:
# -> 3283     out = out * weight + bias
#    3285 out = _maybe_convert_to_dtype(out, input.dtype)  # type: ignore[assignment]
#    3286 if input.device.type in ["cpu", "mtia"]:
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_prims_common\wrappers.py:308, in out_wrapper.<locals>._out_wrapper.<locals>._fn(out, *args, **kwargs)
#     306     result = fn(*args, is_out=(out is not None), **kwargs)  # type: ignore[arg-type]
#     307 else:
# --> 308     result = fn(*args, **kwargs)
#     309 assert (
#     310     (isinstance(result, TensorLike) and is_tensor)
#     311     or (
#    (...)    318     )
#     319 )
#     320 # unbind_copy is a special case: see https://github.com/pytorch/pytorch/issues/130829
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_compile.py:51, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      48     disable_fn = torch._dynamo.disable(fn, recursive)
#      49     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
# ---> 51 return disable_fn(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_dynamo\eval_frame.py:838, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     836 _maybe_set_eval_frame(_callback_from_stance(self.callback))
#     837 try:
# --> 838     return fn(*args, **kwargs)
#     839 finally:
#     840     set_eval_frame(None)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_prims_common\wrappers.py:149, in elementwise_type_promotion_wrapper.__call__.<locals>._fn(*args, **kwargs)
#     142 promoted_args = {
#     143     x: _maybe_convert_to_dtype(bound.arguments[x], compute_dtype)
#     144     for x in self.type_promoting_arg_names  # type: ignore[union-attr]
#     145     if x in bound.arguments.keys()
#     146 }
#     147 bound.arguments.update(promoted_args)
# --> 149 result = fn(**bound.arguments)
#     151 # Override the return_dtype if a dtype arg is present and not None
#     152 if "dtype" in bound.arguments:
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_refs\__init__.py:1086, in _make_elementwise_binary_reference.<locals>.inner.<locals>._ref(a, b)
#    1080 torch._check_value(
#    1081     supports_two_python_scalars
#    1082     or not (isinstance(a, Number) and isinstance(b, Number)),
#    1083     lambda: f"{name}: Receive two Number inputs to an elementwise binary operation!",
#    1084 )
#    1085 a, b = _maybe_broadcast(a, b)
# -> 1086 output = prim(a, b)
#    1087 return handle_noncontiguous_outputs([a, b], output)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_refs\__init__.py:1693, in mul(a, b)
#    1688 @_make_elementwise_binary_reference(
#    1689     type_promotion_kind=ELEMENTWISE_TYPE_PROMOTION_KIND.DEFAULT,
#    1690     supports_two_python_scalars=True,
#    1691 )
#    1692 def mul(a: TensorLikeType, b: TensorLikeType) -> TensorLikeType:
# -> 1693     return prims.mul(a, b)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_ops.py:756, in OpOverload.__call__(self, *args, **kwargs)
#     755 def __call__(self, /, *args, **kwargs):
# --> 756     return self._op(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_library\fake_impl.py:95, in construct_meta_kernel.<locals>.meta_kernel(*args, **kwargs)
#      83     raise RuntimeError(
#      84         f"{qualname} ({source}): You're trying to run this operator "
#      85         f"with meta Tensors (as opposed to FakeTensors), but this "
#    (...)     91         f"torch.library.get_ctx(). Otherwise, please use FakeTensors."
#      92     )
#      94 with set_ctx_getter(error_on_ctx):
# ---> 95     return fake_impl_holder.kernel(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_library\utils.py:32, in Kernel.__call__(self, *args, **kwargs)
#      31 def __call__(self, *args, **kwargs):
# ---> 32     return self.func(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\library.py:1383, in _check_pystubs_once.<locals>.inner(*args, **kwargs)
#    1381 nonlocal checked
#    1382 if checked:
# -> 1383     return func(*args, **kwargs)
#    1385 op = torch._library.utils.lookup_op(qualname)
#    1386 if op._defined_in_python:
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_library\custom_ops.py:622, in CustomOpDef._register_to_dispatcher.<locals>.fake_impl(*args, **kwargs)
#     615         return None
#     616     raise RuntimeError(
#     617         f"There was no fake impl registered for {self}. "
#     618         f"This is necessary for torch.compile/export/fx tracing to work. "
#     619         f"Please use `{self._init_fn.__name__}.register_fake` to add an "
#     620         f"fake impl."
#     621     )
# --> 622 return self._abstract_fn(*args, **kwargs)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_prims\__init__.py:404, in _prim_elementwise_meta(type_promotion, args_with_fixed_dtypes, *args)
#     401 if args_with_fixed_dtypes is not None:
#     402     args_ = list(args_with_fixed_dtypes) + args_
# --> 404 utils.check_same_device(*args_, allow_cpu_scalar_tensors=True)
#     405 utils.check_same_shape(*args_, allow_cpu_scalar_tensors=True)
#     407 l2p_perm = utils.compute_elementwise_output_logical_to_physical_perm(*args_)
#
# File c:\Polimi\Master\2Sem\NLP-Project\.conda\Lib\site-packages\torch\_prims_common\__init__.py:779, in check_same_device(allow_cpu_scalar_tensors, *args)
#     771     if device != arg.device:
#     772         msg = (
#     773             "Tensor on device "
#     774             + str(arg.device)
#    (...)    777             + "!"
#     778         )
# --> 779         raise RuntimeError(msg)
#     780 else:
#     781     msg = (
#     782         "Unexpected type when checking for same device, " + str(type(arg)) + "!"
#     783     )
#
# RuntimeError: Tensor on device cpu is not on the expected device meta!
